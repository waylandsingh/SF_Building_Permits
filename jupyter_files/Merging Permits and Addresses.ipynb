# %% [markdown]
# # Permits:
# Due to the difficulty of getting the geopandas module to work, this notebook will focus on cleaning up dates out of range, non-residential properties in the permits, and calculating approval time
#
# ### would be good to turn these into functions which can be applied

# %%
import pandas as pd
import numpy as np
import datetime
import pandas_usaddress

pd.set_option("display.max_columns",None)

def trim_zeros(st):
    if isinstance(st,str):
        if st == '0000':
            return ''
        return st.lstrip('0')
    else:
        return None

# %%
df = pd.read_csv('Building_Permits.csv', low_memory=False)

# %%
df.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Block', 'Lot', 'Street Number',
#        'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
#        'Unit Suffix', 'Description', 'Current Status', 'Current Status Date',
#        'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'Plansets', 'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
#        'Location', 'Record ID', 'SF Find Neighborhoods',
#        'Current Police Districts', 'Current Supervisor Districts',
#        'Analysis Neighborhoods', 'DELETE - Zip Codes',
#        'DELETE - Fire Prevention Districts', 'DELETE - Supervisor Districts',
#        'DELETE - Current Police Districts',
#        'DELETE - Supervisorial_Districts_Waterline_data_from_7pkg_wer3'],
#       dtype='object')

# %%
# drop useless columns
del_cols = df.iloc[:,-5:].columns
df.drop(del_cols, axis=1, inplace=True)

# %% [markdown]
# ### First, restrict the dataset to the last 30 years

# %%
df['Permit Creation Date'] = pd.to_datetime(df['Filed Date'])
df.set_index('Permit Creation Date', inplace = True)

# %%
# July12007 to June302018
# also need to restrict projects that aren't finished yet?
# 
df_permits = df[(df.index >= datetime.datetime(2007,7,1)) & (df.index <= datetime.datetime(2018,6,30))]

# %%
df_permits['Existing Use'].value_counts().head(15)
# Out:
# 1 family dwelling       97609
# apartments              77081
# office                  46791
# 2 family dwelling       46108
# retail sales            14213
# food/beverage hndlng    10275
# tourist hotel/motel      3206
# vacant lot               2264
# warehouse,no frnitur     1612
# residential hotel        1588
# school                   1383
# lending institution      1205
# clinics-medic/dental     1066
# church                   1000
# artist live/work          804
# Name: Existing Use, dtype: int64

# %% [markdown]
# ### Restrict the dataset to only dwellings and apartments

# %%
residences = ['1 family dwelling','apartments','2 family dwelling']
df_res = pd.concat([df_permits.groupby('Existing Use').get_group(r) for r in residences])

# %%
df_res['Existing Use'].value_counts()
# Out:
# 1 family dwelling    97609
# apartments           77081
# 2 family dwelling    46108
# Name: Existing Use, dtype: int64

# %%
df_res.shape
# Out:
# (220798, 46)

# %%
# percemtage of permits with a a valid issue date
df_res['Issued Date'].notna().sum()/df_res['Issued Date'].shape[0]
# Out:
# 0.9575403762715242

# %% [markdown]
# ### approval time(days)

# %%
df_res['Filed Date'] = df_res['Filed Date'].apply(pd.to_datetime)
df_res['Issued Date'] = df_res['Issued Date'].apply(pd.to_datetime)

# %%
df_res['approval_in_days'] = df_res['Issued Date'] - df_res['Filed Date']

# %%
df_res['approval_in_days'].dropna().describe()
# Out:
# count                      211423
# mean      32 days 17:25:28.403248
# std      126 days 01:23:19.318148
# min               0 days 00:00:00
# 25%               0 days 00:00:00
# 50%               0 days 00:00:00
# 75%               4 days 00:00:00
# max            4472 days 00:00:00
# Name: approval_in_days, dtype: object

# %% [markdown]
# ### Clean Address in Series

# %%
df_res['Street Number Suffix'] = df_res['Street Number Suffix'].replace(np.NaN,'')
df_res['Street Suffix'] = df_res['Street Suffix'].replace(np.NaN,'')
df_res['Unit'] = df_res['Unit'].fillna(0).apply(lambda x: str(int(x)) if (int(x)>0) else '')

# %%
df_res['Unit']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-e71e3b8b5d4b> in <module>
# ----> 1 df_res['Unit']
#
# NameError: name 'df_res' is not defined

# %%
df_res['Address'] = (df_res['Street Number'].astype('str') + df_res['Street Number Suffix'].astype('str')
                    + ' ' + df_res['Street Name'].astype('str')  + ' ' + df_res['Street Suffix'].astype('str')
                    + ' ' + df_res['Unit'].astype('str') + ' ' + df_res['Unit Suffix'].astype('str')
                    )
                    
df_res['Address'] = df_res['Address'].apply(lambda x: " ".join(x.strip(' nan').strip(' nan').split()))

# %%
df_res['Address'][df_res['Unit Suffix'].notna()] #checking the appended number suffixes: there WILL BE SOME ISSUES ~1%
# Out:
# Permit Creation Date
# 2007-07-17             1420 La Playa A
# 2007-09-05            422 Vallejo St A
# 2007-09-17           1344 Alabama St B
# 2007-09-27              1575 22nd Av F
# 2007-10-19          292 Arlington St F
#                         ...
# 2018-04-11      4503 18th St RES UPPER
# 2018-04-13    1269 South Van Ness Av D
# 2018-05-16          1619 48th Av UPPER
# 2018-06-04           140 Arguello Bl A
# 2018-06-06           222 Winfield St A
# Name: Address, Length: 3195, dtype: object

# %%
df_res.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition', 'Block',
#        'Lot', 'Street Number', 'Street Number Suffix', 'Street Name',
#        'Street Suffix', 'Unit', 'Unit Suffix', 'Description', 'Current Status',
#        'Current Status Date', 'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'Plansets', 'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
#        'Location', 'Record ID', 'SF Find Neighborhoods',
#        'Current Police Districts', 'Current Supervisor Districts',
#        'Analysis Neighborhoods', 'approval_in_days', 'Address'],
#       dtype='object')

# %%
#pickle the dataframe for later
# path_pickle = './Pickled/df_res_use_addr.pkl'
# df_res.to_pickle(path_pickle)

# %% [markdown]
# ### Cleaned(ish) permits data

# %%
path_pickle = './Pickled/df_res_use_addr.pkl'
df_permits = pd.read_pickle(path_pickle)

# %%
df_permits['Permit Type Definition'].value_counts()
# Out:
# otc alterations permit              202368
# additions alterations or repairs     17799
# demolitions                            404
# sign - erect                           226
# new construction wood frame              1
# Name: Permit Type Definition, dtype: int64

# %% [markdown]
# ### Assessor Data
# Splitting the address and reassembling them in a way that (hopefully?) makes sense
#
# split the property location into :
# 'Street Number', 'Street Number Suffix', 'Street Name',
#        'Street Suffix', 'Unit', 'Unit Suffix'

# %%
df_assess = pd.read_csv('./Assessor Notebooks/Residence Assessor.csv')
# Out:
# /home/jovyan/conda-envs/capstone-dev/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_assess['Property Location'].head(20)
# Out:
# 0      0000 0297 BALTIMORE           WY0000
# 1      0000 0666 POST                ST1503
# 2      0000 0650 CHESTNUT            ST0202
# 3      0000 0611 WASHINGTON          ST2402
# 4      0000 0000                       0000
# 5      0000 1925 LEAVENWORTH         ST0012
# 6      0000 0849 MASON               ST0001
# 7     0000 0690 CHESTNUT            ST0202C
# 8      0000 2001 GRANT               AV0000
# 9     0000 0044 MACONDRAY           LN0006E
# 10     0000 0006 SHARP               PL0000
# 11     0000 0850 POWELL              ST0301
# 12     0000 0240 LOMBARD             ST0289
# 13     0000 1520 TAYLOR              ST0205
# 14     0000 0850 POWELL              ST0903
# 15     0156 0150 LOMBARD             ST0027
# 16     0000 0999 GREEN               ST3101
# 17     0000 1001 PINE                ST1412
# 18    0000 0101 LOMBARD             ST0801W
# 19     0000 0666 FILBERT             ST0000
# Name: Property Location, dtype: object

# %%
def parse_assess_address(series):
    series.apply(lambda x: x.split())
    print(series.apply(lambda x: x.split()))

# %%
parse_assess_address(df_assess['Property Location'].head())
# Out:
# 0     [0000, 0297, BALTIMORE, WY0000]
# 1          [0000, 0666, POST, ST1503]
# 2      [0000, 0650, CHESTNUT, ST0202]
# 3    [0000, 0611, WASHINGTON, ST2402]
# 4                  [0000, 0000, 0000]
# Name: Property Location, dtype: object

# %% [markdown]
# ### Address cleaned - Permits

# %%
df_permits.shape
# Out:
# (220798, 48)

# %%
# altneratively, can try to standardize to s asingle address
addr_cols = ['Street Number', 'Street Name','Street Suffix', 'Unit']

df_tagged_single = pandas_usaddress.tag(df_permits,addr_cols, granularity='single', standardize=True)

# %%
df_tagged_single.head()
# Out:
#                      Permit Number  Permit Type  \
# Permit Creation Date
# 2014-02-03            201402037639            8
# 2017-12-18            201712186766            3
# 2016-08-29            201608296300            3
# 2015-06-02            201506027829            3
# 2016-12-21            201612215583            3
#
#                                 Permit Type Definition Block  Lot  \
# Permit Creation Date
# 2014-02-03                      otc alterations permit  4219  043
# 2017-12-18            additions alterations or repairs  6940  031
# 2016-08-29            additions alterations or repairs  7089  040
# 2015-06-02            additions alterations or repairs  5841  005
# 2016-12-21            additions alterations or repairs  0155  013
#
#                       Street Number Street Number Suffix Street Name  \
# Permit Creation Date
# 2014-02-03                     1123                  NaN    Carolina
# 2017-12-18                      242                  NaN      Ashton
# 2016-08-29                      274                  NaN    Victoria
# 2015-06-02                      423                  NaN      Justin
# 2016-12-21                     1310                  NaN     Pacific
#
#                      Street Suffix  Unit  ...  Zipcode  \
# Permit Creation Date                      ...
# 2014-02-03                      St   NaN  ...  94107.0
# 2017-12-18                      Av   NaN  ...  94112.0
# 2016-08-29                      St   NaN  ...  94132.0
# 2015-06-02                      Dr   NaN  ...  94110.0
# 2016-12-21                      Av   NaN  ...  94109.0
#
#                                                        Location  \
# Permit Creation Date
# 2014-02-03            (37.754306947688534, -122.39931683984678)
# 2017-12-18              (37.7226331255751, -122.46195088679892)
# 2016-08-29             (37.71566908934369, -122.46503924892617)
# 2015-06-02             (37.73195576909413, -122.42389453610747)
# 2016-12-21             (37.79576706146776, -122.41710075064503)
#
#                           Record ID SF Find Neighborhoods  \
# Permit Creation Date
# 2014-02-03            1331529172376                  54.0
# 2017-12-18            1491022214718                  64.0
# 2016-08-29            1435480220959                  65.0
# 2015-06-02            1383635189245                  93.0
# 2016-12-21             144822060927                  16.0
#
#                      Current Police Districts Current Supervisor Districts  \
# Permit Creation Date
# 2014-02-03                                2.0                          9.0
# 2017-12-18                               10.0                          8.0
# 2016-08-29                               10.0                          1.0
# 2015-06-02                                9.0                          2.0
# 2016-12-21                                6.0                          3.0
#
#                      Analysis Neighborhoods approval_in_days  \
# Permit Creation Date
# 2014-02-03                             26.0              NaN
# 2017-12-18                             24.0              NaN
# 2016-08-29                             24.0              NaN
# 2015-06-02                              2.0              NaN
# 2016-12-21                             32.0              NaN
#
#                                Address        SingleLine
# Permit Creation Date
# 2014-02-03            1123 Carolina St  1123 carolina st
# 2017-12-18               242 Ashton Av    242 ashton ave
# 2016-08-29             274 Victoria St   274 victoria st
# 2015-06-02               423 Justin Dr     423 justin dr
# 2016-12-21             1310 Pacific Av  1310 pacific ave
#
# [5 rows x 49 columns]

# %%
df_tagged_single['SingleLine']
# Out:
# Permit Creation Date
# 2014-02-03       1123 carolina st
# 2017-12-18         242 ashton ave
# 2016-08-29        274 victoria st
# 2015-06-02          423 justin dr
# 2016-12-21       1310 pacific ave
#                      ...
# 2016-05-27           4971 17th st
# 2015-12-15    1270 fitzgerald ave
# 2018-02-22    1272 fitzgerald ave
# 2018-03-22         3533 market st
# 2009-02-20         684 sanchez st
# Name: SingleLine, Length: 220798, dtype: object

# %% [markdown]
# ### Load Clean Permits

# %%
path_pickle = './Pickled/df_addr_clean.pkl'
# df_tagged_single.to_pickle(path_pickle)
df_permits_clean = pd.read_pickle(path_pickle)

# %%
df_permits_clean.SingleLine.head(5)
# Out:
# Permit Creation Date
# 2014-02-03    1123 carolina st
# 2017-12-18      242 ashton ave
# 2016-08-29     274 victoria st
# 2015-06-02       423 justin dr
# 2016-12-21    1310 pacific ave
# Name: SingleLine, dtype: object

# %% [markdown]
# ### Fixing Assessors and merging with pandas usaaddress
# `granularity='single', standardize=True)`

# %%
df_assessor = pd.read_csv('Assessor_Notebooks/Residence_Assessor.csv')
# Out:
# /home/jovyan/conda-envs/capstone-dev/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_assessor.rename(columns={'Unnamed: 0':'assess_id'}, inplace=True)

# %%
dropcols = ['Supervisor District', 'Analysis Neighborhood',
       'the_geom', 'Row ID', 'SF Find Neighborhoods',
       'Current Police Districts', 'Current Supervisor Districts',
       'Analysis Neighborhoods',]
df_assessor.drop(dropcols, axis=1, inplace=True)
df_assessor.columns
# Out:
# Index(['assess_id', 'Closed Roll Year', 'Property Location', 'Parcel Number',
#        'Block', 'Lot', 'Volume Number', 'Use Code', 'Use Definition',
#        'Property Class Code', 'Property Class Code Definition',
#        'Year Property Built', 'Number of Bathrooms', 'Number of Bedrooms',
#        'Number of Rooms', 'Number of Stories', 'Number of Units',
#        'Zoning Code', 'Construction Type', 'Lot Depth', 'Lot Frontage',
#        'Property Area', 'Basement Area', 'Lot Area', 'Lot Code',
#        'Tax Rate Area Code', 'Percent of Ownership', 'Exemption Code',
#        'Exemption Code Definition', 'Status Code', 'Misc Exemption Value',
#        'Homeowner Exemption Value', 'Current Sales Date',
#        'Assessed Fixtures Value', 'Assessed Improvement Value',
#        'Assessed Land Value', 'Assessed Personal Property Value',
#        'Assessor Neighborhood District', 'Assessor Neighborhood Code',
#        'Assessor Neighborhood'],
#       dtype='object')

# %%
# 'Lot', 'Street Number', 'Street Number Suffix', 'Street Name',
#        'Street Suffix', 'Unit', 'Unit Suffix'

# %%
df_assessor['Lot'] = df_assessor['Property Location'].str.extract(r'(\d\d\d\d\s)', expand=True)
df_assessor['Street Number'] = df_assessor['Property Location'].str.extract(r'(?:\d\d\d\d\s)(\d\d\d\d\s)', expand=True)
df_assessor['Street Number'] = df_assessor['Street Number'].apply(trim_zeros)
df_assessor['Street Name'] = df_assessor['Property Location'].str.extract(r'(?:\d\d\d\d\s)(?:\d\d\d\d\s+)(.*)(?:\s+\w\w\d\d\d\d)', expand=True)
df_assessor['Street Suffix'] = df_assessor['Property Location'].str.extract(r'(?:\d\d\d\d\s)(?:\d\d\d\d\s+)(?:.*)(?:\s+)(\w\w)(?:\d\d\d\d)', expand=True)
df_assessor['Unit'] = df_assessor['Property Location'].str.extract(r'(?:\d\d\d\d\s)(?:\d\d\d\d\s+)(?:.*)(?:\s+)(?:\w\w)(\d\d\d\d)', expand=True)
df_assessor['Unit'] = df_assessor['Unit'].apply(trim_zeros)
df_assessor.head(3)
# Out:
#    assess_id  Closed Roll Year                     Property Location  \
# 0          3            2009.0  0000 0297 BALTIMORE           WY0000
# 1          8            2007.0  0000 0666 POST                ST1503
# 2          9            2007.0  0000 0650 CHESTNUT            ST0202
#
#   Parcel Number  Block    Lot  Volume Number Use Code  \
# 0       6499040   6499  0000              38     SRES
# 1      0298C050  0298C  0000               3     SRES
# 2       0051091   0051  0000               1     SRES
#
#               Use Definition Property Class Code  ...  \
# 0  Single Family Residential                   D  ...
# 1  Single Family Residential                 COS  ...
# 2  Single Family Residential                   Z  ...
#
#   Assessed Improvement Value  Assessed Land Value  \
# 0                      45734                22044
# 1                     143223                35803
# 2                     284690               122009
#
#    Assessed Personal Property Value  Assessor Neighborhood District  \
# 0                                 0                            10.0
# 1                                 0                             8.0
# 2                                 0                             8.0
#
#    Assessor Neighborhood Code  Assessor Neighborhood  Street Number  \
# 0                         10B          Croker Amazon           297
# 1                          8A               Downtown           666
# 2                          8D            North Beach           650
#
#            Street Name Street Suffix  Unit
# 0  BALTIMORE                      WY
# 1  POST                           ST  1503
# 2  CHESTNUT                       ST   202
#
# [3 rows x 44 columns]

# %%
# data set is too large: separate the ID, address columns, them add the standardized address to the original
addr_cols = ['Street Number', 'Street Name','Street Suffix', 'Unit']
addr_only = df_assessor[addr_cols]
addr_only.head()
# Out:
#   Street Number          Street Name Street Suffix  Unit
# 0          297   BALTIMORE                      WY
# 1          666   POST                           ST  1503
# 2          650   CHESTNUT                       ST   202
# 3          611   WASHINGTON                     ST  2402
# 4                                NaN           NaN  None

# %%
addr_cols = ['Street Number', 'Street Name','Street Suffix', 'Unit']
std_addresses = pandas_usaddress.tag(addr_only, addr_cols, granularity='single', standardize=True)
std_addresses.head()
# Out:
#   Street Number          Street Name Street Suffix  Unit  \
# 0          297   BALTIMORE                      WY   NaN
# 1          666   POST                           ST  1503
# 2          650   CHESTNUT                       ST   202
# 3          611   WASHINGTON                     ST  2402
# 4                                NaN           NaN   NaN
#
#                SingleLine
# 0       297 baltimore way
# 1        666 post st 1503
# 2     650 chestnut st 202
# 3  611 washington st 2402
# 4                     NaN

# %%
#JOIN the addresses by the index to make df_assessor_tagged
df_assessor['SingleLine'] = std_addresses['SingleLine']
df_assessor.head(2)
# Out:
#    assess_id  Closed Roll Year                     Property Location  \
# 0          3            2009.0  0000 0297 BALTIMORE           WY0000
# 1          8            2007.0  0000 0666 POST                ST1503
#
#   Parcel Number  Block    Lot  Volume Number Use Code  \
# 0       6499040   6499  0000              38     SRES
# 1      0298C050  0298C  0000               3     SRES
#
#               Use Definition Property Class Code  ... Assessed Land Value  \
# 0  Single Family Residential                   D  ...               22044
# 1  Single Family Residential                 COS  ...               35803
#
#    Assessed Personal Property Value  Assessor Neighborhood District  \
# 0                                 0                            10.0
# 1                                 0                             8.0
#
#    Assessor Neighborhood Code  Assessor Neighborhood  Street Number  \
# 0                         10B          Croker Amazon           297
# 1                          8A               Downtown           666
#
#            Street Name Street Suffix  Unit         SingleLine
# 0  BALTIMORE                      WY        297 baltimore way
# 1  POST                           ST  1503   666 post st 1503
#
# [2 rows x 45 columns]

# %% [markdown]
# ### Load Clean Assessments

# %%
path_pickle = './Pickled/df_assess_clean.pkl'
# df_assessor.to_pickle(path_pickle)
df_assess_clean = pd.read_pickle(path_pickle)

# %%
df_assess_clean.head(1)
# Out:
#    assess_id  Closed Roll Year                     Property Location  \
# 0          3            2009.0  0000 0297 BALTIMORE           WY0000
#
#   Parcel Number Block    Lot  Volume Number Use Code  \
# 0       6499040  6499  0000              38     SRES
#
#               Use Definition Property Class Code  ... Assessed Land Value  \
# 0  Single Family Residential                   D  ...               22044
#
#    Assessed Personal Property Value  Assessor Neighborhood District  \
# 0                                 0                            10.0
#
#    Assessor Neighborhood Code  Assessor Neighborhood  Street Number  \
# 0                         10B          Croker Amazon           297
#
#            Street Name Street Suffix Unit         SingleLine
# 0  BALTIMORE                      WY       297 baltimore way
#
# [1 rows x 45 columns]

# %% [markdown]
# ### To merge, fix year to datetime (assessments)

# %%
df_assess_clean.rename(columns={'Closed Roll Year':'Year'},inplace=True)

# %%
df_assess_clean['Year'] = pd.to_datetime(df_assess_clean['Year'], format='%Y').dt.year
df_assess_clean['Year']= df_assess_clean['Year'].fillna(-1).astype(int)

# %%
df_assess_clean.loc[:,['Year', 'SingleLine']]
# Out:
#          Year                SingleLine
# 0        2009         297 baltimore way
# 1        2007          666 post st 1503
# 2        2007       650 chestnut st 202
# 3        2007    611 washington st 2402
# 4        2007                       NaN
# ...       ...                       ...
# 1783686  2016  588 mission bay north bl
# 1783687  2016               1180 4th st
# 1783688  2016               1180 4th st
# 1783689  2016               1000 3rd st
# 1783690  2016            110 channel st
#
# [1783691 rows x 2 columns]

# %% [markdown]
# ### To merge, split year off from datetime

# %%
df_permits_clean['Year'] = df_permits_clean.index.year

# %%
df_permits_clean.head()
# Out:
#                      Permit Number  Permit Type  \
# Permit Creation Date
# 2014-02-03            201402037639            8
# 2017-12-18            201712186766            3
# 2016-08-29            201608296300            3
# 2015-06-02            201506027829            3
# 2016-12-21            201612215583            3
#
#                                 Permit Type Definition Block  Lot  \
# Permit Creation Date
# 2014-02-03                      otc alterations permit  4219  043
# 2017-12-18            additions alterations or repairs  6940  031
# 2016-08-29            additions alterations or repairs  7089  040
# 2015-06-02            additions alterations or repairs  5841  005
# 2016-12-21            additions alterations or repairs  0155  013
#
#                       Street Number Street Number Suffix Street Name  \
# Permit Creation Date
# 2014-02-03                     1123                  NaN    Carolina
# 2017-12-18                      242                  NaN      Ashton
# 2016-08-29                      274                  NaN    Victoria
# 2015-06-02                      423                  NaN      Justin
# 2016-12-21                     1310                  NaN     Pacific
#
#                      Street Suffix  Unit  ...  \
# Permit Creation Date                      ...
# 2014-02-03                      St   NaN  ...
# 2017-12-18                      Av   NaN  ...
# 2016-08-29                      St   NaN  ...
# 2015-06-02                      Dr   NaN  ...
# 2016-12-21                      Av   NaN  ...
#
#                                                        Location  \
# Permit Creation Date
# 2014-02-03            (37.754306947688534, -122.39931683984678)
# 2017-12-18              (37.7226331255751, -122.46195088679892)
# 2016-08-29             (37.71566908934369, -122.46503924892617)
# 2015-06-02             (37.73195576909413, -122.42389453610747)
# 2016-12-21             (37.79576706146776, -122.41710075064503)
#
#                           Record ID SF Find Neighborhoods  \
# Permit Creation Date
# 2014-02-03            1331529172376                  54.0
# 2017-12-18            1491022214718                  64.0
# 2016-08-29            1435480220959                  65.0
# 2015-06-02            1383635189245                  93.0
# 2016-12-21             144822060927                  16.0
#
#                      Current Police Districts Current Supervisor Districts  \
# Permit Creation Date
# 2014-02-03                                2.0                          9.0
# 2017-12-18                               10.0                          8.0
# 2016-08-29                               10.0                          1.0
# 2015-06-02                                9.0                          2.0
# 2016-12-21                                6.0                          3.0
#
#                      Analysis Neighborhoods approval_in_days  \
# Permit Creation Date
# 2014-02-03                             26.0              NaN
# 2017-12-18                             24.0              NaN
# 2016-08-29                             24.0              NaN
# 2015-06-02                              2.0              NaN
# 2016-12-21                             32.0              NaN
#
#                                Address        SingleLine  Year
# Permit Creation Date
# 2014-02-03            1123 Carolina St  1123 carolina st  2014
# 2017-12-18               242 Ashton Av    242 ashton ave  2017
# 2016-08-29             274 Victoria St   274 victoria st  2016
# 2015-06-02               423 Justin Dr     423 justin dr  2015
# 2016-12-21             1310 Pacific Av  1310 pacific ave  2016
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Merge on address, year, using .join

# %%
pc = df_permits_clean.columns
ac = df_assess_clean.columns
common_cols = [item in pc for item in ac]
ac[common_cols]
# Out:
# Index(['Year', 'Block', 'Lot', 'Street Number', 'Street Name', 'Street Suffix',
#        'Unit', 'SingleLine'],
#       dtype='object')

# %%
#drop rows from both where either address OR year is Null
# Out:
# Index(['Year', 'Block', 'Lot', 'Street Number', 'Street Name', 'Street Suffix',
#        'Unit', 'SingleLine'],
#       dtype='object')

# %%
merge_cols = ['Year','SingleLine']
small_permit = df_permits_clean.iloc[:].dropna(axis=0, subset=merge_cols)
small_assess = df_assess_clean.iloc[:].dropna(subset=merge_cols)
small_merge = pd.merge(left = small_permit,right=small_assess, on=merge_cols, how='inner')

# %%
small_merge.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition', 'Block_x',
#        'Lot_x', 'Street Number_x', 'Street Number Suffix', 'Street Name_x',
#        'Street Suffix_x', 'Unit_x', 'Unit Suffix', 'Description',
#        'Current Status', 'Current Status Date', 'Filed Date', 'Issued Date',
#        'Completed Date', 'First Construction Document Date',
#        'Structural Notification', 'Number of Existing Stories',
#        'Number of Proposed Stories', 'Voluntary Soft-Story Retrofit',
#        'Fire Only Permit', 'Permit Expiration Date', 'Estimated Cost',
#        'Revised Cost', 'Existing Use', 'Existing Units', 'Proposed Use',
#        'Proposed Units', 'Plansets', 'TIDF Compliance',
#        'Existing Construction Type', 'Existing Construction Type Description',
#        'Proposed Construction Type', 'Proposed Construction Type Description',
#        'Site Permit', 'Supervisor District',
#        'Neighborhoods - Analysis Boundaries', 'Zipcode', 'Location',
#        'Record ID', 'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'approval_in_days', 'Address', 'SingleLine', 'Year', 'assess_id',
#        'Property Location', 'Parcel Number', 'Block_y', 'Lot_y',
#        'Volume Number', 'Use Code', 'Use Definition', 'Property Class Code',
#        'Property Class Code Definition', 'Year Property Built',
#        'Number of Bathrooms', 'Number of Bedrooms', 'Number of Rooms',
#        'Number of Stories', 'Number of Units', 'Zoning Code',
#        'Construction Type', 'Lot Depth', 'Lot Frontage', 'Property Area',
#        'Basement Area', 'Lot Area', 'Lot Code', 'Tax Rate Area Code',
#        'Percent of Ownership', 'Exemption Code', 'Exemption Code Definition',
#        'Status Code', 'Misc Exemption Value', 'Homeowner Exemption Value',
#        'Current Sales Date', 'Assessed Fixtures Value',
#        'Assessed Improvement Value', 'Assessed Land Value',
#        'Assessed Personal Property Value', 'Assessor Neighborhood District',
#        'Assessor Neighborhood Code', 'Assessor Neighborhood',
#        'Street Number_y', 'Street Name_y', 'Street Suffix_y', 'Unit_y'],
#       dtype='object')

# %%
small_merge.set_index('Permit Number', inplace=True)

# %%
[print(entry) for entry in small_merge['SingleLine'].head(100)]
# Out:
# 242 ashton ave
# 242 ashton ave
# 242 ashton ave
# 274 victoria st
# 274 victoria st
# 1310 pacific ave
# 1310 pacific ave
# 1751 silver ave
# 1751 silver ave
# 1762 11th ave
# 80 oliver st
# 80 oliver st
# 89 norton st
# 1741 16th ave
# 1741 16th ave
# 1741 16th ave
# 2558 21st ave
# 224 brazil ave
# 676 capp st
# 676 capp st
# 78 rotteck st
# 78 rotteck st
# 601 42nd ave
# 601 42nd ave
# 510 22nd ave
# 842 monterey bl
# 2238 kirkham st
# 1922 48th ave
# 476 39th ave
# 3817 26th st
# 3817 26th st
# 3817 26th st
# 3817 26th st
# 3125 lincoln way
# 3125 lincoln way
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 721 ashbury st
# 95 laidley st
# 1698 27th ave
# 1698 27th ave
# 194 maddux ave
# 194 maddux ave
# 194 maddux ave
# 366 sussex st
# 366 sussex st
# 366 sussex st
# 215 kenwood way
# 215 kenwood way
# 1053 tennessee st
# 1053 tennessee st
# 1053 tennessee st
# 1053 tennessee st
# 227 randolph st
# 227 randolph st
# 227 randolph st
# 427 joost ave
# 427 joost ave
# 427 joost ave
# 368 princeton st
# 368 princeton st
# 368 princeton st
# 96 seminole ave
# 3949 21st st
# 2016 14th ave
# 2016 14th ave
# 2016 14th ave
# 1299 fitzgerald ave
# 1299 fitzgerald ave
# 10 gilroy st
# 1553 45th ave
# 1553 45th ave
# 3014 sacramento st
# 3014 sacramento st
# 2 ankeny st
# 1559 07th ave
# 1559 07th ave
# 1027 santiago st
# 1574 33rd ave
# 159 sadowa st
# 159 sadowa st
# 101 urbano dr
# 56 laura st
# 56 laura st
# 56 laura st
# 701 brunswick st
# 1050 page st
# 1050 page st
# 1050 page st
# 1050 page st
# 107 17th ave
# 45 broad st
# 45 broad st
# 1621 irving st
# 1621 irving st
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Remove Unneeded Columns & save

# %%
path_pickle = './Pickled/merged_permit_assess.pkl'
# small_merge.to_pickle(path_pickle)
permit_assess = pd.read_pickle(path_pickle)

# %%
permit_assess.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition', 'Block_x',
#        'Lot_x', 'Street Number_x', 'Street Number Suffix', 'Street Name_x',
#        'Street Suffix_x', 'Unit_x', 'Unit Suffix', 'Description',
#        'Current Status', 'Current Status Date', 'Filed Date', 'Issued Date',
#        'Completed Date', 'First Construction Document Date',
#        'Structural Notification', 'Number of Existing Stories',
#        'Number of Proposed Stories', 'Voluntary Soft-Story Retrofit',
#        'Fire Only Permit', 'Permit Expiration Date', 'Estimated Cost',
#        'Revised Cost', 'Existing Use', 'Existing Units', 'Proposed Use',
#        'Proposed Units', 'Plansets', 'TIDF Compliance',
#        'Existing Construction Type', 'Existing Construction Type Description',
#        'Proposed Construction Type', 'Proposed Construction Type Description',
#        'Site Permit', 'Supervisor District',
#        'Neighborhoods - Analysis Boundaries', 'Zipcode', 'Location',
#        'Record ID', 'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'approval_in_days', 'Address', 'SingleLine', 'Year', 'assess_id',
#        'Property Location', 'Parcel Number', 'Block_y', 'Lot_y',
#        'Volume Number', 'Use Code', 'Use Definition', 'Property Class Code',
#        'Property Class Code Definition', 'Year Property Built',
#        'Number of Bathrooms', 'Number of Bedrooms', 'Number of Rooms',
#        'Number of Stories', 'Number of Units', 'Zoning Code',
#        'Construction Type', 'Lot Depth', 'Lot Frontage', 'Property Area',
#        'Basement Area', 'Lot Area', 'Lot Code', 'Tax Rate Area Code',
#        'Percent of Ownership', 'Exemption Code', 'Exemption Code Definition',
#        'Status Code', 'Misc Exemption Value', 'Homeowner Exemption Value',
#        'Current Sales Date', 'Assessed Fixtures Value',
#        'Assessed Improvement Value', 'Assessed Land Value',
#        'Assessed Personal Property Value', 'Assessor Neighborhood District',
#        'Assessor Neighborhood Code', 'Assessor Neighborhood',
#        'Street Number_y', 'Street Name_y', 'Street Suffix_y', 'Unit_y'],
#       dtype='object')

# %%
drop_cols = ['Block_x',
       'Lot_x', 'Street Number_x', 'Street Number Suffix', 'Street Name_x',
       'Street Suffix_x', 'Unit_x', 'Unit Suffix', 'Property Location', 'Parcel Number', 'Block_y', 'Lot_y',
         'Street Number_y', 'Street Name_y', 'Street Suffix_y', 'Unit_y']

# %%
permit_assess.drop(drop_cols, axis=1, inplace=True)

# %%
mostly_na = permit_assess.isna().sum().to_frame()

#remove any column with more than 1/3 missing data. Make sure completed date isn't here (needed for approval time!)
na_cols = list(mostly_na[mostly_na[0]>permit_assess.shape[0]/3].index.values)

# %%
permit_assess.drop(na_cols, axis=1, inplace=True)

# %% [markdown]
# ### Filter out reeeeeally slow approvals (>4years)

# %%
365*4
# Out:
# 1460

# %%
year_filter = permit_assess['approval_in_days']<pd.to_timedelta('1461 days 00:00:00.00000')

# %%
permit_assess = permit_assess[year_filter]

# %%
permit_assess.shape
# Out:
# (124502, 65)

# %%
permit_assess.dtypes.to_frame().transpose()
# Out:
#   Permit Number Permit Type Permit Type Definition Description Current Status  \
# 0        object       int64                 object      object         object
#
#   Current Status Date      Filed Date Issued Date Completed Date  \
# 0              object  datetime64[ns]      object         object
#
#   Number of Existing Stories Number of Proposed Stories  \
# 0                    float64                    float64
#
#   Permit Expiration Date Estimated Cost Revised Cost Existing Use  \
# 0                 object        float64      float64       object
#
#   Existing Units Proposed Use Proposed Units Plansets  \
# 0        float64       object        float64  float64
#
#   Existing Construction Type Existing Construction Type Description  \
# 0                    float64                                 object
#
#   Proposed Construction Type Proposed Construction Type Description  \
# 0                     object                                 object
#
#   Supervisor District Neighborhoods - Analysis Boundaries  Zipcode Location  \
# 0             float64                              object  float64   object
#
#   Record ID SF Find Neighborhoods Current Police Districts  \
# 0     int64               float64                  float64
#
#   Current Supervisor Districts Analysis Neighborhoods approval_in_days  \
# 0                      float64                float64           object
#
#   Address SingleLine   Year assess_id Volume Number Use Code Use Definition  \
# 0  object     object  int64     int64         int64   object         object
#
#   Property Class Code Property Class Code Definition Number of Bathrooms  \
# 0              object                         object             float64
#
#   Number of Bedrooms Number of Rooms Number of Stories Number of Units  \
# 0              int64           int64             int64           int64
#
#   Zoning Code Construction Type Lot Depth Lot Frontage Property Area  \
# 0      object            object   float64      float64         int64
#
#   Basement Area Lot Area Tax Rate Area Code Percent of Ownership  \
# 0         int64  float64            float64              float64
#
#   Misc Exemption Value Homeowner Exemption Value Assessed Fixtures Value  \
# 0                int64                     int64                   int64
#
#   Assessed Improvement Value Assessed Land Value  \
# 0                      int64               int64
#
#   Assessed Personal Property Value Assessor Neighborhood District  \
# 0                            int64                        float64
#
#   Assessor Neighborhood Code Assessor Neighborhood
# 0                     object                object

# %% [markdown]
# ### filter out only completed projects - not needed

# %%
permit_assess['Current Status'].value_counts()
# Out:
# complete      93006
# issued        23296
# expired        6679
# cancelled      1010
# reinstated      245
# suspend         114
# withdrawn        91
# revoked          58
# approved          2
# denied            1
# Name: Current Status, dtype: int64

# %% [markdown]
# ### delta_stories and delta_units

# %%
permit_assess['delta_stories'] = permit_assess['Number of Proposed Stories'] - permit_assess['Number of Existing Stories']

# %%
permit_assess['delta_units'] = permit_assess['Proposed Units'] - permit_assess['Existing Units']

# %%
permit_assess['Issued Date'] = pd.to_datetime(permit_assess['Issued Date'])

# %%
permit_assess['approve_days'] = (permit_assess['Issued Date'] - permit_assess['Filed Date']).dt.days

# %%
permit_assess.dtypes.to_frame().transpose()
# Out:
#   Permit Number Permit Type Permit Type Definition Description Current Status  \
# 0        object       int64                 object      object         object
#
#   Current Status Date      Filed Date     Issued Date Completed Date  \
# 0              object  datetime64[ns]  datetime64[ns]         object
#
#   Number of Existing Stories Number of Proposed Stories  \
# 0                    float64                    float64
#
#   Permit Expiration Date Estimated Cost Revised Cost Existing Use  \
# 0                 object        float64      float64       object
#
#   Existing Units Proposed Use Proposed Units Plansets  \
# 0        float64       object        float64  float64
#
#   Existing Construction Type Existing Construction Type Description  \
# 0                    float64                                 object
#
#   Proposed Construction Type Proposed Construction Type Description  \
# 0                     object                                 object
#
#   Supervisor District Neighborhoods - Analysis Boundaries  Zipcode Location  \
# 0             float64                              object  float64   object
#
#   Record ID SF Find Neighborhoods Current Police Districts  \
# 0     int64               float64                  float64
#
#   Current Supervisor Districts Analysis Neighborhoods approval_in_days  \
# 0                      float64                float64           object
#
#   Address SingleLine   Year assess_id Volume Number Use Code Use Definition  \
# 0  object     object  int64     int64         int64   object         object
#
#   Property Class Code Property Class Code Definition Number of Bathrooms  \
# 0              object                         object             float64
#
#   Number of Bedrooms Number of Rooms Number of Stories Number of Units  \
# 0              int64           int64             int64           int64
#
#   Zoning Code Construction Type Lot Depth Lot Frontage Property Area  \
# 0      object            object   float64      float64         int64
#
#   Basement Area Lot Area Tax Rate Area Code Percent of Ownership  \
# 0         int64  float64            float64              float64
#
#   Misc Exemption Value Homeowner Exemption Value Assessed Fixtures Value  \
# 0                int64                     int64                   int64
#
#   Assessed Improvement Value Assessed Land Value  \
# 0                      int64               int64
#
#   Assessed Personal Property Value Assessor Neighborhood District  \
# 0                            int64                        float64
#
#   Assessor Neighborhood Code Assessor Neighborhood delta_stories delta_units  \
# 0                     object                object       float64     float64
#
#   approve_days
# 0        int64

# %%
path_pickle = './Pickled/ml_ready.pkl'
permit_assess.to_pickle(path_pickle)
ml_ready = pd.read_pickle(path_pickle)

# %%
ml_ready
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 3       201707242676            8            otc alterations permit
# 4       201708084132            8            otc alterations permit
# 6       201608296300            3  additions alterations or repairs
# 8       201609157815            8            otc alterations permit
# 10      201610210942            3  additions alterations or repairs
# ...              ...          ...                               ...
# 129451  201706159518            3  additions alterations or repairs
# 129452  201703060745            3  additions alterations or repairs
# 129453  201703060745            3  additions alterations or repairs
# 129454  201701308229            3  additions alterations or repairs
# 129455  201711063192            3  additions alterations or repairs
#
#                                               Description Current Status  \
# 3       replace (11) windows not visible from street, ...       complete
# 4       replace 6 windows visible from street; no stru...       complete
# 6       comply with nov 201625382 permit for furnace/w...         issued
# 8       replace (e) brick foundation in kind with conc...       complete
# 10      unit legalization ord #43-14. interior alterat...         issued
# ...                                                   ...            ...
# 129451  renovation of kitchen, bathroom & bedroom @ al...       complete
# 129452  adu: (n) dwelling unit being added at ground l...         issued
# 129453  adu: (n) dwelling unit being added at ground l...         issued
# 129454  rear addition to (e) dwelling units. total 4 n...         issued
# 129455  addition of dwelling unit per ordinance #162-1...         issued
#
#        Current Status Date Filed Date Issued Date Completed Date  \
# 3               08/28/2017 2017-07-24  2017-07-24     08/28/2017
# 4               01/18/2018 2017-08-08  2017-08-08     01/18/2018
# 6               05/30/2019 2016-08-29  2019-05-30            NaN
# 8               01/22/2018 2016-09-15  2016-10-06     01/22/2018
# 10              01/17/2019 2016-10-21  2019-01-17            NaN
# ...                    ...        ...         ...            ...
# 129451          10/22/2019 2017-06-15  2018-06-05     10/22/2019
# 129452          11/07/2018 2017-03-06  2018-11-07            NaN
# 129453          11/07/2018 2017-03-06  2018-11-07            NaN
# 129454          01/07/2020 2017-01-30  2020-01-07            NaN
# 129455          01/13/2020 2017-11-06  2020-01-13            NaN
#
#         Number of Existing Stories  Number of Proposed Stories  \
# 3                              2.0                         2.0
# 4                              2.0                         2.0
# 6                              2.0                         2.0
# 8                              2.0                         2.0
# 10                             2.0                         2.0
# ...                            ...                         ...
# 129451                         3.0                         3.0
# 129452                         4.0                         4.0
# 129453                         4.0                         4.0
# 129454                         2.0                         2.0
# 129455                         3.0                         3.0
#
#        Permit Expiration Date  Estimated Cost  Revised Cost  \
# 3                  07/19/2018         12804.0       12804.0
# 4                  08/03/2018          8550.0        8550.0
# 6                  05/24/2020         21000.0       45000.0
# 8                  10/01/2017         40000.0       88400.0
# 10                 01/01/2022         40000.0      240000.0
# ...                       ...             ...           ...
# 129451             05/20/2021        200000.0      400000.0
# 129452             10/22/2021        150000.0      150000.0
# 129453             10/22/2021        150000.0      150000.0
# 129454             01/07/2021        220000.0      220000.0
# 129455             01/13/2021        125000.0      125000.0
#
#              Existing Use  Existing Units       Proposed Use  Proposed Units  \
# 3       1 family dwelling             1.0  1 family dwelling             1.0
# 4       1 family dwelling             1.0  1 family dwelling             1.0
# 6       1 family dwelling             1.0  2 family dwelling             2.0
# 8       1 family dwelling             1.0  1 family dwelling             1.0
# 10      1 family dwelling             1.0  2 family dwelling             2.0
# ...                   ...             ...                ...             ...
# 129451  2 family dwelling             2.0         apartments             3.0
# 129452  2 family dwelling             2.0         apartments             3.0
# 129453  2 family dwelling             2.0         apartments             3.0
# 129454  2 family dwelling             2.0  2 family dwelling             2.0
# 129455  2 family dwelling             2.0         apartments             3.0
#
#         Plansets  Existing Construction Type  \
# 3            0.0                         5.0
# 4            0.0                         5.0
# 6            2.0                         5.0
# 8            2.0                         5.0
# 10           2.0                         5.0
# ...          ...                         ...
# 129451       2.0                         5.0
# 129452       2.0                         5.0
# 129453       2.0                         5.0
# 129454       2.0                         5.0
# 129455       2.0                         5.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 3                              wood frame (5)                          5
# 4                              wood frame (5)                          5
# 6                              wood frame (5)                          5
# 8                              wood frame (5)                          5
# 10                             wood frame (5)                          5
# ...                                       ...                        ...
# 129451                         wood frame (5)                          5
# 129452                         wood frame (5)                          5
# 129453                         wood frame (5)                          5
# 129454                         wood frame (5)                          5
# 129455                         wood frame (5)                          5
#
#        Proposed Construction Type Description  Supervisor District  \
# 3                              wood frame (5)                  7.0
# 4                              wood frame (5)                  7.0
# 6                              wood frame (5)                 11.0
# 8                              wood frame (5)                  3.0
# 10                             wood frame (5)                 10.0
# ...                                       ...                  ...
# 129451                         wood frame (5)                  2.0
# 129452                         wood frame (5)                  8.0
# 129453                         wood frame (5)                  8.0
# 129454                         wood frame (5)                 11.0
# 129455                         wood frame (5)                  3.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 3               Oceanview/Merced/Ingleside  94112.0
# 4               Oceanview/Merced/Ingleside  94112.0
# 6               Oceanview/Merced/Ingleside  94132.0
# 8                             Russian Hill  94109.0
# 10                   Bayview Hunters Point  94124.0
# ...                                    ...      ...
# 129451                              Marina  94123.0
# 129452                             Mission  94103.0
# 129453                             Mission  94103.0
# 129454                           Excelsior  94112.0
# 129455                         North Beach  94133.0
#
#                                          Location      Record ID  \
# 3       (37.722633125765405, -122.46195088671291)  1471551214718
# 4       (37.722633125765405, -122.46195088671291)  1473665214718
# 6        (37.71566908950004, -122.46503924884911)  1554232514844
# 8       (37.795767061509025, -122.41710075059225)   143753060927
# 10        (37.73391776288098, -122.4032854512375)  1538268513959
# ...                                           ...            ...
# 129451   (37.80294730876713, -122.43022505192417)  1510015511652
# 129452    (37.7685953869372, -122.42528803605241)  1530809513398
# 129453    (37.7685953869372, -122.42528803605241)  1530810509589
# 129454   (37.72087604975688, -122.43153215338197)  1576788505698
# 129455   (37.80192903470591, -122.40725137791523)  1581525516425
#
#         SF Find Neighborhoods  Current Police Districts  \
# 3                        64.0                      10.0
# 4                        64.0                      10.0
# 6                        65.0                      10.0
# 8                        16.0                       6.0
# 10                       87.0                       2.0
# ...                       ...                       ...
# 129451                   17.0                       4.0
# 129452                   37.0                       3.0
# 129453                   37.0                       3.0
# 129454                   90.0                       9.0
# 129455                   18.0                       6.0
#
#         Current Supervisor Districts  Analysis Neighborhoods  \
# 3                                8.0                    24.0
# 4                                8.0                    24.0
# 6                                1.0                    24.0
# 8                                3.0                    32.0
# 10                               9.0                     1.0
# ...                              ...                     ...
# 129451                           6.0                    13.0
# 129452                           5.0                    20.0
# 129453                           5.0                    20.0
# 129454                           1.0                     7.0
# 129455                           3.0                    23.0
#
#           approval_in_days           Address        SingleLine  Year  \
# 3          0 days 00:00:00     242 Ashton Av    242 ashton ave  2017
# 4          0 days 00:00:00     242 Ashton Av    242 ashton ave  2017
# 6       1004 days 00:00:00  274A Victoria St   274 victoria st  2016
# 8         21 days 00:00:00   1310 Pacific Av  1310 pacific ave  2016
# 10       818 days 00:00:00   1751A Silver Av   1751 silver ave  2016
# ...                    ...               ...               ...   ...
# 129451   355 days 00:00:00  3325A Octavia St   3325 octavia st  2017
# 129452   611 days 00:00:00   41A Rosemont Pl    41 rosemont pl  2017
# 129453   611 days 00:00:00    41 Rosemont Pl    41 rosemont pl  2017
# 129454  1072 days 00:00:00     502 Naples St     502 naples st  2017
# 129455   798 days 00:00:00   462A Filbert St    462 filbert st  2017
#
#         assess_id  Volume Number Use Code             Use Definition  \
# 3         1803809             41     SRES  Single Family Residential
# 4         1803809             41     SRES  Single Family Residential
# 6         2018919             42     SRES  Single Family Residential
# 8         1831052              2     MRES   Multi-Family Residential
# 10        1977365             32     SRES  Single Family Residential
# ...           ...            ...      ...                        ...
# 129451    1641316              4     MRES   Multi-Family Residential
# 129452    1730745             23     SRES  Single Family Residential
# 129453    1730745             23     SRES  Single Family Residential
# 129454    1796752             36     MRES   Multi-Family Residential
# 129455    1626739              1     SRES  Single Family Residential
#
#        Property Class Code Property Class Code Definition  \
# 3                        D                       Dwelling
# 4                        D                       Dwelling
# 6                        D                       Dwelling
# 8                       FS   Flat & Store 4 units or less
# 10                       D                       Dwelling
# ...                    ...                            ...
# 129451                   F                 Flats & Duplex
# 129452                   Z                    Condominium
# 129453                   Z                    Condominium
# 129454                  FS   Flat & Store 4 units or less
# 129455                   Z                    Condominium
#
#         Number of Bathrooms  Number of Bedrooms  Number of Rooms  \
# 3                       2.0                   0                5
# 4                       2.0                   0                5
# 6                       1.0                   0                5
# 8                       1.0                   0                8
# 10                      2.0                   0                8
# ...                     ...                 ...              ...
# 129451                  3.0                   0               13
# 129452                  3.0                   4               12
# 129453                  3.0                   4               12
# 129454                  2.0                   0                8
# 129455                  1.0                   2                4
#
#         Number of Stories  Number of Units Zoning Code Construction Type  \
# 3                       1                1         RH1                 D
# 4                       1                1         RH1                 D
# 6                       1                1         RH1                 D
# 8                       2                2         NC2                 D
# 10                      1                1         RH1                 D
# ...                   ...              ...         ...               ...
# 129451                  2                3         RH3                 D
# 129452                  2                0         NaN                 D
# 129453                  2                0         NaN                 D
# 129454                  2                3         RH1                 D
# 129455                  1                0         NaN               NaN
#
#         Lot Depth  Lot Frontage  Property Area  Basement Area  Lot Area  \
# 3             0.0           0.0           1250              0    2809.0
# 4             0.0           0.0           1250              0    2809.0
# 6             0.0           0.0           1255              0    2495.0
# 8             0.0           0.0           2332              0    1197.0
# 10            0.0           0.0           1896              0    2513.0
# ...           ...           ...            ...            ...       ...
# 129451        0.0           0.0           3645              0    2495.0
# 129452        0.0           0.0           2086              0       0.0
# 129453        0.0           0.0           2086              0       0.0
# 129454        0.0           0.0           2175              0    2495.0
# 129455        0.0           0.0            829              0       0.0
#
#         Tax Rate Area Code  Percent of Ownership  Misc Exemption Value  \
# 3                   1000.0                   1.0                     0
# 4                   1000.0                   1.0                     0
# 6                   1000.0                   0.5                     0
# 8                   1000.0                   1.0                     0
# 10                  1000.0                   0.5                     0
# ...                    ...                   ...                   ...
# 129451              1000.0                   1.0                     0
# 129452              1000.0                   0.5                     0
# 129453              1000.0                   0.5                     0
# 129454              1000.0                   1.0                     0
# 129455              1000.0                   1.0                     0
#
#         Homeowner Exemption Value  Assessed Fixtures Value  \
# 3                            7000                        0
# 4                            7000                        0
# 6                            7000                        0
# 8                               0                        0
# 10                              0                        0
# ...                           ...                      ...
# 129451                          0                        0
# 129452                          0                        0
# 129453                          0                        0
# 129454                          0                        0
# 129455                          0                        0
#
#         Assessed Improvement Value  Assessed Land Value  \
# 3                           119595                60676
# 4                           119595                60676
# 6                           180566               421328
# 8                           127796                42512
# 10                          171424               399997
# ...                            ...                  ...
# 129451                      997500              2327500
# 129452                       92166               138258
# 129453                       92166               138258
# 129454                      232329               135074
# 129455                      522219               522219
#
#         Assessed Personal Property Value  Assessor Neighborhood District  \
# 3                                      0                             3.0
# 4                                      0                             3.0
# 6                                      0                             3.0
# 8                                      0                             8.0
# 10                                     0                            10.0
# ...                                  ...                             ...
# 129451                                 0                             7.0
# 129452                                 0                             5.0
# 129453                                 0                             5.0
# 129454                                 0                            10.0
# 129455                                 0                             8.0
#
#        Assessor Neighborhood Code Assessor Neighborhood  delta_stories  \
# 3                              3H             Ingleside            0.0
# 4                              3H             Ingleside            0.0
# 6                              3G     Ingleside Heights            0.0
# 8                              8C              Nob Hill            0.0
# 10                            10G        Silver Terrace            0.0
# ...                           ...                   ...            ...
# 129451                         7A                Marina            0.0
# 129452                         5M       Mission Dolores            0.0
# 129453                         5M       Mission Dolores            0.0
# 129454                        10C             Excelsior            0.0
# 129455                         8G        Telegraph Hill            0.0
#
#         delta_units  approve_days
# 3               0.0             0
# 4               0.0             0
# 6               1.0          1004
# 8               0.0            21
# 10              1.0           818
# ...             ...           ...
# 129451          1.0           355
# 129452          1.0           611
# 129453          1.0           611
# 129454          0.0          1072
# 129455          1.0           798
#
# [124502 rows x 68 columns]
